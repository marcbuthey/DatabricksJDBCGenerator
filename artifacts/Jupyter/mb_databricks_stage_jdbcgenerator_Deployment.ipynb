# %%
# StageHeader

# %%
# StageTable: customer_order_products_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_customer_order_products`""")

spark.sql("""CREATE TABLE `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_customer_order_products` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`order_id` Integer NOT NULL
    ,`order_tms` Timestamp NOT NULL
    ,`order_status` String NOT NULL
    ,`customer_id` Integer NOT NULL
    ,`email_address` String NOT NULL
    ,`full_name` String NOT NULL
    ,`order_total` Decimal(38,2)
    ,`items` String
)
USING delta
"""
)

# %%
# StageSourceView: customer_order_products_Stage Source View_1

# %%
# StageResultView: customer_order_products_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_customer_order_products_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`order_id` AS `order_id`
    ,`bg_source`.`order_tms` AS `order_tms`
    ,`bg_source`.`order_status` AS `order_status`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`email_address` AS `email_address`
    ,`bg_source`.`full_name` AS `full_name`
    ,`bg_source`.`order_total` AS `order_total`
    ,`bg_source`.`items` AS `items`
FROM `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_customer_order_products` AS `bg_source`
""")

# %%
# StageTable: customers_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_customers`""")

spark.sql("""CREATE TABLE `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_customers` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`customer_id` Integer NOT NULL
    ,`email_address` String NOT NULL
    ,`full_name` String NOT NULL
)
USING delta
"""
)

# %%
# StageSourceView: customers_Stage Source View_1

# %%
# StageResultView: customers_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_customers_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`email_address` AS `email_address`
    ,`bg_source`.`full_name` AS `full_name`
FROM `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_customers` AS `bg_source`
""")

# %%
# StageTable: inventory_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_inventory`""")

spark.sql("""CREATE TABLE `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_inventory` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`inventory_id` Integer NOT NULL
    ,`store_id` Integer NOT NULL
    ,`product_id` Integer NOT NULL
    ,`product_inventory` Integer NOT NULL
)
USING delta
"""
)

# %%
# StageSourceView: inventory_Stage Source View_1

# %%
# StageResultView: inventory_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_inventory_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`inventory_id` AS `inventory_id`
    ,`bg_source`.`store_id` AS `store_id`
    ,`bg_source`.`product_id` AS `product_id`
    ,`bg_source`.`product_inventory` AS `product_inventory`
FROM `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_inventory` AS `bg_source`
""")

# %%
# StageTable: order_items_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_order_items`""")

spark.sql("""CREATE TABLE `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_order_items` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`order_id` Integer NOT NULL
    ,`line_item_id` Integer NOT NULL
    ,`product_id` Integer NOT NULL
    ,`unit_price` Decimal(10,2) NOT NULL
    ,`quantity` Integer NOT NULL
    ,`shipment_id` Integer
)
USING delta
"""
)

# %%
# StageSourceView: order_items_Stage Source View_1

# %%
# StageResultView: order_items_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_order_items_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`order_id` AS `order_id`
    ,`bg_source`.`line_item_id` AS `line_item_id`
    ,`bg_source`.`product_id` AS `product_id`
    ,`bg_source`.`unit_price` AS `unit_price`
    ,`bg_source`.`quantity` AS `quantity`
    ,`bg_source`.`shipment_id` AS `shipment_id`
FROM `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_order_items` AS `bg_source`
""")

# %%
# StageTable: orders_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_orders`""")

spark.sql("""CREATE TABLE `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_orders` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`order_id` Integer NOT NULL
    ,`order_tms` Timestamp NOT NULL
    ,`customer_id` Integer NOT NULL
    ,`order_status` String NOT NULL
    ,`store_id` Integer NOT NULL
)
USING delta
"""
)

# %%
# StageSourceView: orders_Stage Source View_1

# %%
# StageResultView: orders_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_orders_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`order_id` AS `order_id`
    ,`bg_source`.`order_tms` AS `order_tms`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`order_status` AS `order_status`
    ,`bg_source`.`store_id` AS `store_id`
FROM `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_orders` AS `bg_source`
""")

# %%
# StageTable: product_orders_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_product_orders`""")

spark.sql("""CREATE TABLE `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_product_orders` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`product_name` String NOT NULL
    ,`order_status` String NOT NULL
    ,`total_sales` Decimal(38,2)
    ,`order_count` Integer
)
USING delta
"""
)

# %%
# StageSourceView: product_orders_Stage Source View_1

# %%
# StageResultView: product_orders_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_product_orders_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`product_name` AS `product_name`
    ,`bg_source`.`order_status` AS `order_status`
    ,`bg_source`.`total_sales` AS `total_sales`
    ,`bg_source`.`order_count` AS `order_count`
FROM `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_product_orders` AS `bg_source`
""")

# %%
# StageTable: product_reviews_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_product_reviews`""")

spark.sql("""CREATE TABLE `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_product_reviews` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`product_name` String NOT NULL
    ,`rating` Integer
    ,`avg_rating` Integer
    ,`review` String
)
USING delta
"""
)

# %%
# StageSourceView: product_reviews_Stage Source View_1

# %%
# StageResultView: product_reviews_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_product_reviews_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`product_name` AS `product_name`
    ,`bg_source`.`rating` AS `rating`
    ,`bg_source`.`avg_rating` AS `avg_rating`
    ,`bg_source`.`review` AS `review`
FROM `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_product_reviews` AS `bg_source`
""")

# %%
# StageTable: products_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_products`""")

spark.sql("""CREATE TABLE `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_products` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`product_id` Integer NOT NULL
    ,`product_name` String NOT NULL
    ,`unit_price` Decimal(10,2)
    ,`product_details` Binary
    ,`product_image` Binary
    ,`image_mime_type` String
    ,`image_filename` String
    ,`image_charset` String
    ,`image_last_updated` Timestamp
)
USING delta
"""
)

# %%
# StageSourceView: products_Stage Source View_1

# %%
# StageResultView: products_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_products_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`product_id` AS `product_id`
    ,`bg_source`.`product_name` AS `product_name`
    ,`bg_source`.`unit_price` AS `unit_price`
    ,`bg_source`.`product_details` AS `product_details`
    ,`bg_source`.`product_image` AS `product_image`
    ,`bg_source`.`image_mime_type` AS `image_mime_type`
    ,`bg_source`.`image_filename` AS `image_filename`
    ,`bg_source`.`image_charset` AS `image_charset`
    ,`bg_source`.`image_last_updated` AS `image_last_updated`
FROM `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_products` AS `bg_source`
""")

# %%
# StageTable: shipments_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_shipments`""")

spark.sql("""CREATE TABLE `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_shipments` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`shipment_id` Integer NOT NULL
    ,`store_id` Integer NOT NULL
    ,`customer_id` Integer NOT NULL
    ,`delivery_address` String NOT NULL
    ,`shipment_status` String NOT NULL
)
USING delta
"""
)

# %%
# StageSourceView: shipments_Stage Source View_1

# %%
# StageResultView: shipments_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_shipments_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`shipment_id` AS `shipment_id`
    ,`bg_source`.`store_id` AS `store_id`
    ,`bg_source`.`customer_id` AS `customer_id`
    ,`bg_source`.`delivery_address` AS `delivery_address`
    ,`bg_source`.`shipment_status` AS `shipment_status`
FROM `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_shipments` AS `bg_source`
""")

# %%
# StageTable: store_orders_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_store_orders`""")

spark.sql("""CREATE TABLE `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_store_orders` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`total` String
    ,`store_name` String
    ,`address` String
    ,`latitude` Decimal(9,6)
    ,`longitude` Decimal(9,6)
    ,`order_status` String
    ,`order_count` Integer
    ,`total_sales` Decimal(38,2)
)
USING delta
"""
)

# %%
# StageSourceView: store_orders_Stage Source View_1

# %%
# StageResultView: store_orders_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_store_orders_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`total` AS `total`
    ,`bg_source`.`store_name` AS `store_name`
    ,`bg_source`.`address` AS `address`
    ,`bg_source`.`latitude` AS `latitude`
    ,`bg_source`.`longitude` AS `longitude`
    ,`bg_source`.`order_status` AS `order_status`
    ,`bg_source`.`order_count` AS `order_count`
    ,`bg_source`.`total_sales` AS `total_sales`
FROM `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_store_orders` AS `bg_source`
""")

# %%
# StageTable: stores_Stage Table_1
spark.sql("""DROP TABLE IF EXISTS `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_stores`""")

spark.sql("""CREATE TABLE `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_stores` (
     `bg_loadtimestamp` Timestamp NOT NULL
    ,`bg_sourcesystem` String
    ,`store_id` Integer NOT NULL
    ,`store_name` String NOT NULL
    ,`web_address` String
    ,`physical_address` String
    ,`latitude` Decimal(9,6)
    ,`longitude` Decimal(9,6)
    ,`logo` Binary
    ,`logo_mime_type` String
    ,`logo_filename` String
    ,`logo_charset` String
    ,`logo_last_updated` Timestamp
)
USING delta
"""
)

# %%
# StageSourceView: stores_Stage Source View_1

# %%
# StageResultView: stores_Stage Result View_1
spark.sql(f"""CREATE OR REPLACE VIEW `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_stores_result`
AS
SELECT
     `bg_source`.`bg_loadtimestamp` AS `bg_loadtimestamp`
    ,`bg_source`.`bg_sourcesystem` AS `bg_sourcesystem`
    ,`bg_source`.`store_id` AS `store_id`
    ,`bg_source`.`store_name` AS `store_name`
    ,`bg_source`.`web_address` AS `web_address`
    ,`bg_source`.`physical_address` AS `physical_address`
    ,`bg_source`.`latitude` AS `latitude`
    ,`bg_source`.`longitude` AS `longitude`
    ,`bg_source`.`logo` AS `logo`
    ,`bg_source`.`logo_mime_type` AS `logo_mime_type`
    ,`bg_source`.`logo_filename` AS `logo_filename`
    ,`bg_source`.`logo_charset` AS `logo_charset`
    ,`bg_source`.`logo_last_updated` AS `logo_last_updated`
FROM `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_stores` AS `bg_source`
""")

# %%
# StageFooter
