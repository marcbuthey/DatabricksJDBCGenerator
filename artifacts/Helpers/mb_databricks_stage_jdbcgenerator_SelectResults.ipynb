# %%
df = spark.sql("""
    select '`{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_customer_order_products_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_customer_order_products_result`
    union
    select '`{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_customers_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_customers_result`
    union
    select '`{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_inventory_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_inventory_result`
    union
    select '`{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_order_items_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_order_items_result`
    union
    select '`{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_orders_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_orders_result`
    union
    select '`{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_product_orders_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_product_orders_result`
    union
    select '`{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_product_reviews_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_product_reviews_result`
    union
    select '`{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_products_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_products_result`
    union
    select '`{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_shipments_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_shipments_result`
    union
    select '`{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_store_orders_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_store_orders_result`
    union
    select '`{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_stores_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{mb_databricks_stage_jdbcgenerator#stage#database_name}`.`{mb_databricks_stage_jdbcgenerator#stage#schema_name}`.`stg_st_stores_result`
""")
df.show(n=1000, truncate=False)
